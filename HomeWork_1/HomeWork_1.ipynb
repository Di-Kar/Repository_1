# %%
import cianparser

moscow_parser = cianparser.CianParser(location="Москва")
data = moscow_parser.get_flats(deal_type="sale", rooms=(1, 2), with_saving_csv=True, additional_settings={"start_page":1, "end_page":2})

print(data[0])

# %%
import pandas as pd
my_path = r'C:\Users\Mitrich\Documents\Repository_1\HomeWork_1'
df = pd.read_csv(f'{my_path}\\cian_flat_sale_1_20_moskva_02_Jul_2024_07_18_32_781576.csv', sep = ';')
df
# Out:
#                           author        author_type  \
# 0                         VESPER          developer
# 1                        SHOW ME  real_estate_agent
# 2                       MR Group          developer
# 3                    ID 73038306  real_estate_agent
# 4               Галс-Девелопмент          developer
# ..                           ...                ...
# 539                   Арт Риэлти  real_estate_agent
# 540  Century 21 Premium Property  real_estate_agent
# 541                    Whitewill  real_estate_agent
# 542                    Whitewill  real_estate_agent
# 543                    Whitewill  real_estate_agent
#
#                                           url location deal_type  \
# 0    https://www.cian.ru/sale/flat/262519758/   Москва      sale
# 1    https://www.cian.ru/sale/flat/302081797/   Москва      sale
# 2    https://www.cian.ru/sale/flat/294196808/   Москва      sale
# 3    https://www.cian.ru/sale/flat/301180623/   Москва      sale
# ...

# %%
df.to_pickle(f'{my_path}\\cian_Moscow.pkl')

# %%
df.to_excel(f'{my_path}\\cian_Moscow.xlsx')

# %%
import sqlite3
conn = sqlite3.connect(f'{my_path}\\cian_Moscow.db')
df.to_sql('cian_Moscow', conn, if_exists='replace', index = False)
conn.commit()
conn.close()
