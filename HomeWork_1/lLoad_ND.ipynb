# %%
import requests
import pandas as pd

# %%
offset_ = 1 # размер шага
limit_ = 100 # количество объектов в одном ответе api
header = {'User-Agent': 'My User Agent 1.0','Content-Type':'application/json'}
# header = {}
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url, headers = header)
print(res.headers['content-type'])
objects_data = res.json()
objects_data.get('data').get('list')[0]
# print(res.content)
# Out:
# application/json;charset=UTF-8
# {'hobjId': 37165,
#  'objId': 13398,
#  'developer': {'devId': 306,
#   'shortName': '2МЕН ГРУПП',
#   'fullName': '2МЕН ГРУПП',
#   'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#   'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#   'companyGroup': 5776,
#   'devInn': '7701651356'},
#  'rpdRegionCd': 72,
#  'objAddr': 'г. Тюмень, ул Профсоюзная, д. 56',
#  'shortAddr': 'г. Тюмень, ул Профсоюзная',
#  'objGreenHouseFlg': 0,
#  'objFloorMin': 7,
#  'objFloorMax': 10,
#  'objElemLivingCnt': 43,
#  'objReady100PercDt': '2024-12-31',
#  'objSquareLiving': 4812.98,
#  'objCompensFundFlg': 0,
#  'objProblemFlg': 0,
#  'latitude': 57.1519,
#  'longitude': 65.5544,
#  'problemFlag': 'NONE',
#  'siteStatus': 'Строящиеся',
#  'objGuarantyEscrowFlg': 0,
#  'residentialBuildings': 1,
#  'rpdNum': '72-000097',
#  'pdId': 28141,
#  'buildType': 'Жилое',
#  'objStatus': 0,
# ...

# %%
requests.chardet_version
# Out:
# '4.0.0'

# %%
df_nashdom = pd.DataFrame(objects_data.get('data').get('list'))
len(df_nashdom)
# Out:
# 1500

# %%
df_nashdom.head()
# Out:
#    hobjId  objId                                          developer  \
# 0   37165  13398  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 1   37201  13397  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 2  141653  60880  {'devId': 17196, 'shortName': 'CЗ ИМПУЛЬС', 'f...
# 3  136720  56006  {'devId': 3980, 'shortName': 'АВАЛОН', 'fullNa...
# 4  141900  61087  {'devId': 18874, 'shortName': 'АГРО-СТРОЙ', 'f...
#
#    rpdRegionCd                           objAddr  \
# 0           72  г. Тюмень, ул Профсоюзная, д. 56
# 1           72  г. Тюмень, ул Профсоюзная, д. 56
# 2           77        г. Москва, ул Котляковская
# 3           54   г. Новосибирск, район Советский
# 4            7                     город Нальчик
#
#                          shortAddr  objGreenHouseFlg  objFloorMin  \
# 0        г. Тюмень, ул Профсоюзная                 0            7
# 1        г. Тюмень, ул Профсоюзная                 0            6
# ...

# %%
df_nashdom.to_excel('df_nashdom.xlsx', index = False)

# %%
df_nashdom.to_csv('df_nashdom.csv',sep = ';', index = False)

# %%
df_nashdom.to_pickle('df_nashdom.pkl')

# %%
df_nashdom1 = pd.read_pickle('df_nashdom.pkl')
df_nashdom1.head()
# Out:
#    hobjId  objId                                          developer  \
# 0   37165  13398  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 1   37201  13397  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 2  141653  60880  {'devId': 17196, 'shortName': 'CЗ ИМПУЛЬС', 'f...
# 3  136720  56006  {'devId': 3980, 'shortName': 'АВАЛОН', 'fullNa...
# 4  141900  61087  {'devId': 18874, 'shortName': 'АГРО-СТРОЙ', 'f...
#
#    rpdRegionCd                           objAddr  \
# 0           72  г. Тюмень, ул Профсоюзная, д. 56
# 1           72  г. Тюмень, ул Профсоюзная, д. 56
# 2           77        г. Москва, ул Котляковская
# 3           54   г. Новосибирск, район Советский
# 4            7                     город Нальчик
#
#                          shortAddr  objGreenHouseFlg  objFloorMin  \
# 0        г. Тюмень, ул Профсоюзная                 0            7
# 1        г. Тюмень, ул Профсоюзная                 0            6
# ...
